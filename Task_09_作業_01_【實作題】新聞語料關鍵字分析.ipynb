# %% [markdown]
# <a href="https://colab.research.google.com/github/smc147258/-Python-/blob/main/Task_09_%E4%BD%9C%E6%A5%AD_01_%E3%80%90%E5%AF%A6%E4%BD%9C%E9%A1%8C%E3%80%91%E6%96%B0%E8%81%9E%E8%AA%9E%E6%96%99%E9%97%9C%E9%8D%B5%E5%AD%97%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

news = []

for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href']
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)
print(news)
# Out:
# ['上市公司去年年報申報告一段落，據臺灣證券交易所最新統計，本國及第一上市公司(含創新板公司)除隆銘綠能（3018）及如興（4414）外，均已申報2022年度財務報告。 \r 證交所表示，本國及第一上市公司(含創新板公司)應於今年3月31日前公告申報2022年度財務報告家數分別為781家及75家，合計856家（不含實收資本額達新台幣100億元以上及金融保險業上市公司計122家，已依規於今年3月16日前申報完畢），除隆銘綠能及如興無法如期出具財務報告外，其餘均已完成申報作業。                 上市公司 創新板', '北台灣一位知名的N姓體育教練因培養出奧運奪牌選手，在體壇頗具威望，卻未料他私下對女選手伸魔爪，一位同樣是明日之星的體壇正妹小婷，便從國中起就被迫與教練性交，多次在外出比賽期間，還要滿足教練，比賽成績不如預期，就要用身體向教練「懺悔」，直到成年後才不再隱忍提告，法院判教練有期徒刑2年3個月、不得緩刑。 \r 據了解，N姓教練在北部某國中擔任體育教練，並在學校組織下招收女學生，不少在國際賽事上奪牌的選手，都曾接受過N姓教練指導，因奧運賽事中指導選手奪牌為國爭光，N姓教練更曾多次登上新聞版面，還曾接受過官員接見，在體壇地位不一般。            \r 不過N姓教練卻對其中一名女選手伸魔爪，小婷從國中起便加入體育隊接受訓練，但在國三那年卻大變樣，小婷甚至在學校教室都被迫與教練發生關係，甚至多次外出比賽期間入住飯店，都被迫到教練房間報到。 \r 判決書指出，小婷在2010年4月間參加在台東舉辦的全中運，卻因排名賽成績不理想，令N姓教練不悅，小婷遂到教練房間道歉，小婷稱「我為了讓他不要那麼生氣，就跟他發生性交」。 \r 小婷在法庭上證稱，因學校體育教室的教練休息室，只有經過教練同意才能入內，因此她國三期間，多次被教練叫進休息室內發生關係「最頻繁的時候每周會有2到3次，每個月至少1次」，甚至中午11點多下課被教練以要談事情為由叫去「我就知道他是要幹嘛」，更指教練會把休息室門鎖上後，在休息室內的L型沙發對她行性交行為。 \r 小婷在判決書中表示，會跟N發生性交行為是因為他是教練，也希望自己成績更好，在認知上，不要違抗教練在體罰上可以輕一點，使用器材上也比較不會被刁難，念國一到國三，都有不想繼續練習，因為教練很嚴厲，但自從跟教練發生性行為後，教練
# ...

# %%
# 安裝 jieba 中文斷詞套件
# !pip install jieba 

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big


# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# --2023-04-01 13:34:41--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘dict.txt.big.1’
#
# dict.txt.big.1      100%[===================>]   8.18M  --.-KB/s    in 0.03s
#
# 2023-04-01 13:34:41 (294 MB/s) - ‘dict.txt.big.1’ saved [8583143/8583143]

# %%
word_count = {}
for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
for i in token:
  if i not in word_count:
    word_count[i] = 1
  else:
    word_count[i] += 1
print(word_count)
# Out:
# {'今天': 4, '華南': 2, '雲雨': 3, '區': 3, '東移': 2, '，': 20, '截至': 1, '目前': 1, '為': 2, '止': 1, '的': 4, '累積': 1, '雨量': 1, '集中': 1, '在': 3, '苗栗': 1, '、': 6, '台': 2, '中': 1, '。': 6, '中央': 1, '氣象': 1, '局長': 1, '鄭': 2, '明': 2, '典': 2, '臉': 1, '書': 1, '表示': 1, '雨帶': 2, '還': 2, '沒': 1, '完全': 1, '通過': 1, '一條': 1, '幾乎': 1, '不': 1, '動': 1, '雨': 1, '型': 1, '像': 1, '灣': 2, '掛': 1, '了': 1, '彩': 1, '帶': 1, '會': 2, '持續': 1, '到': 5, '下午': 1, ' ': 23, '\r': 3, '氣象局': 2, '說': 1, '出來': 1, '增多': 1, '降雨': 5, '比': 1, '昨天': 1, '明顯': 3, '清晨': 1, '中部': 4, '以北': 3, '開始': 1, '有些': 1, '白天': 2, '是': 1, '最': 1, '時段': 1, '北部': 1, '及': 5, '東北部': 1, '有': 3, '陣雨': 3, '花': 2, '東': 1, '地區': 5, '南部': 2, '山區': 2, '也': 2, '局部': 3, '短暫': 2, '容易': 1, '出現': 1, '較大': 1, '雨勢': 2, '平地': 1, '機率': 1, '則': 2, '相對': 1, '較': 2, '低': 1, '晚上': 1, '之後': 1, '逐漸': 1, '離開': 1, '各地': 1, '趨緩': 1, '北台': 1, '天氣': 1, '涼': 2, '早晚': 1, '低溫': 2, '16': 1, '18': 1, '度': 4, '其他': 3, '地方': 2, '約': 1, '19': 1, '20': 2, '宜': 1, '高溫': 1, '24': 1, '感受': 1, '稍':
# ...

# %%
word_count = dict(sorted(word_count.items(), key=lambda item: item[1], reverse=True))
print(word_count)
# Out:
# {' ': 23, '，': 20, '、': 6, '。': 6, '到': 5, '降雨': 5, '及': 5, '地區': 5, '今天': 4, '的': 4, '中部': 4, '度': 4, '雲雨': 3, '區': 3, '在': 3, '\r': 3, '明顯': 3, '以北': 3, '有': 3, '陣雨': 3, '局部': 3, '其他': 3, '華南': 2, '東移': 2, '為': 2, '台': 2, '鄭': 2, '明': 2, '典': 2, '雨帶': 2, '還': 2, '灣': 2, '會': 2, '氣象局': 2, '白天': 2, '花': 2, '南部': 2, '山區': 2, '也': 2, '短暫': 2, '雨勢': 2, '則': 2, '較': 2, '涼': 2, '低溫': 2, '地方': 2, '20': 2, '截至': 1, '目前': 1, '止': 1, '累積': 1, '雨量': 1, '集中': 1, '苗栗': 1, '中': 1, '中央': 1, '氣象': 1, '局長': 1, '臉': 1, '書': 1, '表示': 1, '沒': 1, '完全': 1, '通過': 1, '一條': 1, '幾乎': 1, '不': 1, '動': 1, '雨': 1, '型': 1, '像': 1, '掛': 1, '了': 1, '彩': 1, '帶': 1, '持續': 1, '下午': 1, '說': 1, '出來': 1, '增多': 1, '比': 1, '昨天': 1, '清晨': 1, '開始': 1, '有些': 1, '是': 1, '最': 1, '時段': 1, '北部': 1, '東北部': 1, '東': 1, '容易': 1, '出現': 1, '較大': 1, '平地': 1, '機率': 1, '相對': 1, '低': 1, '晚上': 1, '之後': 1, '逐漸': 1, '離開': 1, '各地': 1, '趨緩': 1, '北台': 1, '天氣': 1, '早晚': 1, '16': 1, '18': 1, '約': 1, '19': 1, '宜': 1, '高溫': 1, '24': 1, '感受': 1, '稍':
# ...
